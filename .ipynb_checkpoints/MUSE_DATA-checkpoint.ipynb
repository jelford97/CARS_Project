# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
hdu=fits.open('/Users/jelford/Documents/PhD_Work/CARS_Data/HE10291831/HE1029-1831.MUSE.WFM-NOAO.maps-full.fits')

# %%
hdr=hdu[23].header

# %%
print(hdr)
# Out:
# XTENSION= 'IMAGE   '           / Image extension                                BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  317                                                  NAXIS2  =                  314                                                  PCOUNT  =                    0 / number of parameters                           GCOUNT  =                    1 / number of groups                               EXTNAME = 'NII6583 '           / extension name                                 BUNIT   = 'erg/s/cm**2'                                                         CRPIX1  =    156.5136413574219                                                  CRPIX2  =    219.7466735839844                                                  CD1_1   = -5.5555555555555E-05                                                  CD1_2   =                  0.0        
# ...

# %%
OIII=hdu[11].data

# %%
plt.imshow(OIII[150:300,50:250])

# %%
OIIIsum=np.nansum(OIII)

# %%
Hbeta=hdu[13].data

# %%
plt.imshow(Hbeta)

# %%
Hbetasum=np.nansum(Hbeta)

# %%
print(OIIIsum/Hbetasum)
# Out:
# -0.01621786

# %%
Halpha=hdu[9].data

# %%
plt.imshow(Halpha)

# %%
Halphasum=np.nansum(Halpha)

# %%
NII=hdu[23].data

# %%
plt.imshow(NII)

# %%
NIIsum=np.nansum(NII)

# %%
print(NIIsum/Halphasum)
# Out:
# 1.471857
